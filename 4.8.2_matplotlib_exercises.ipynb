# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1 Use matplotlib to plot the following equation:
#
# y = x2 − x + 2
#
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = range(-50,50)
y = [n**2 - n + 2 for n in x]

plt.plot(x, y, c="navy")
plt.text(-3, 300, '(0,0)', fontsize=10, color="green")
plt.show()

# %% [markdown]
# ### 2 Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
#
#
#
# y = √x
#
# y = x3
#
# y = tan(x)
#
# y = 2x
#
#
#
# You can use functions from the math module to help implement some of the equations above.

# %%
import math

x = range(1,100)
y = [(math.sqrt(x)) for x in x]

plt.plot(x,y)
plt.show()

# %%
x = list(range(1,50))
y = [n ** 3 for n in x]

plt.plot(x,y)
plt.show()

# %%
x = range(1,10) 
y = [math.tan(n) for n in x]

plt.plot(x, y)
plt.show()

# %%
x = range(1,50)
y = [2**n for n in x]

plt.plot(y)
plt.show()

# %% [markdown]
# ### 3.) Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(16, 6))
x = range(1,15)

y1 = [(math.sqrt(x)) for x in x]
y2 = [(x * 3) for x in x]
y3 = [math.tan(n) for n in x]
y4 = [(x*2) for x in x]


plt.subplot(221)
plt.plot(x, y1, c="Orange")

plt.subplot(222)
plt.plot(x, y2, c="blue")

plt.subplot(223)
plt.plot(x, y3, c="red")

plt.subplot(224)
plt.plot(x, y4, c="pink")
plt.show()

# %% [markdown]
# ### 4.) Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend.

# %%
import math
x = range(1,50)

y1 = [math.sqrt(n) for n in x]
y2 = [n**3 for n in x]
y3 = [math.tan(n) for n in x]
y4 = [2**n for n in x]

plt.figure(figsize=(14, 6))

plt.scatter(x, y1, c="orange")
plt.scatter(x, y2, c="blue")
plt.scatter(x, y3, c="red")
plt.scatter(x, y4, c="pink")


plt.ylim(-25, 25)
plt.xlim(0, 12)
plt.plot(x, y1, c="Orange", label="ST0NKZ")
plt.plot(x, y2, c="blue", label="B0NDZ")
plt.plot(x, y3, c="red", label="FUNDZ")
plt.plot(x, y4, c="pink", label="P0UNDZ")

plt.legend(loc="upper left")
plt.title("Stock Market Offical Cash Monies")
plt.xlabel("$$$")
plt.show()
