# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pydataset

import seaborn as sns

# %% [markdown]
# ## Use the iris database to answer the following quesitons:

# %%
iris = sns.load_dataset('iris')
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### 1.) What does the distribution of petal lengths look like?

# %%
sns.distplot(iris.petal_length)
plt.show()

# %% [markdown]
# ### 2.) Is there a correlation between petal length and petal width?

# %%
sns.jointplot(data=iris, x='petal_width', y='petal_length')

#plt.subplot(221)
#sns.distplot(df.petal_length)

#plt.subplot(222)
#sns.distplot(df.petal_width)


#sns.pairplot(iris)

# %% [markdown]
# #### yes there is a correlation between petal length and width regarding the size of the flower

# %% [markdown]
# ### 3.) Would it be reasonable to predict species based on sepal width and sepal length?

# %%
plt.figure(figsize=(16, 6))


sns.lmplot(data=iris, x='sepal_width', y='sepal_length', col="species")
plt.show()

# %% [markdown]
# #### the versicolo and virginica species sizes are too similar to use sepal width ansd length to identify the plant.

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### 4.) Which features would be best used to predict species?

# %%
x = 'sepal_length'
y = 'petal_width'
col = 'species'


sns.lmplot(data=iris, x=x, y=y, col=col)

# %%
x = 'sepal_width'
y = 'petal_length'
col = 'species'


sns.lmplot(data=iris, x=x, y=y, col=col)

# %%
x = 'petal_length'
y = 'petal_width'
col = 'species'


sns.lmplot(data=iris, x=x, y=y, col=col)

# %%
x = 'petal_width'
y = 'sepal_length'
col = 'species'


sns.lmplot(data=iris, x=x, y=y, col=col)

# %% [markdown]
# #### i think that petal width and sepal length are a good way to identify the species of the flowers in this dataset
#
#
# - if the sepal length is between 6 & 4 and petal width is less than 1 its a setosa
# - if the sepal length is between 5 & 7 and petal width is between 1 & 1.75 its a versicolor
# - if the sepal length is between 6 & 8 and its petal width is between 1.75 & 2.5 its a virginica

# %% [markdown]
# -------------------------------------------------------------

# %% [markdown]
# ### 1.) Using the lesson as an example, use seaborn's load_dataset function to load the anscombe data set. Use pandas to group the data by the dataset column, and calculate summary statistics for each dataset. What do you notice?

# %%
anscombe = sns.load_dataset('anscombe')

anscombe.info()
anscombe.groupby('dataset').agg(['min', 'max', 'mean'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
# dataset    44 non-null object
# x          44 non-null float64
# y          44 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB
#            x                y
#          min   max mean   min    max      mean
# dataset
# I        4.0  14.0  9.0  4.26  10.84  7.500909
# II       4.0  14.0  9.0  3.10   9.26  7.500909
# III      4.0  14.0  9.0  5.39  12.74  7.500000
# IV       8.0  19.0  9.0  5.25  12.50  7.500909

# %% [markdown]
# - the mean of the x and y axis are consistent throughout datasets I-IV despite varying max and mins in the different datasets

# %% [markdown]
# ### Plot the x and y values from the anscombe data. Each dataset should be in a separate column.

# %%
plt.figure(figsize=(20, 15))


sns.relplot(data=anscombe, x='x', y='y', col='dataset')
plt.show()

# %% [markdown]
# ### 2.) Load the InsectSprays dataset and read it's documentation. Create a boxplot that shows the effectiveness of the different insect sprays.

# %%
insect = pydataset.data('InsectSprays', show_doc=True)
# Out:
# InsectSprays
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Effectiveness of Insect Sprays
#
# ### Description
#
# The counts of insects in agricultural experimental units treated with
# different insecticides.
#
# ### Usage
#
#     InsectSprays
#
# ### Format
#
# A data frame with 72 observations on 2 variables.
#
# [,1]
#
# count
#
# numeric
#
# Insect count
#
# [,2]
#
# spray
#
# factor
#
# The type of spray
#
# ### Source
#
# Beall, G., (1942) The Transformation of data from entomological field
# experiments, _Biometrika_, **29**, 243–262.
#
# ### References
#
# McNeil, D. (1977) _Interactive Data Analysis_. New York: Wiley.
#
# ### Examples
#
#     require(stats); require(graphics)
#     boxplot(count ~ spray, data = InsectSprays,
#             xlab = "Type of spray", ylab = "Insect count",
#             main = "InsectSprays data", varwidth = TRUE, col = "lightgray")
#     fm1 <- aov(count ~ spray, data = InsectSprays)
# ...

# %%
insect = pydataset.data('InsectSprays')

# %%
insect.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 1 to 72
# Data columns (total 2 columns):
# count    72 non-null int64
# spray    72 non-null object
# dtypes: int64(1), object(1)
# memory usage: 1.7+ KB

# %%
plt.figure(figsize=(12, 10))


sns.boxplot(data=insect, y='count', x='spray')
plt.show()

# %% [markdown]
# ### 3.) Load the swiss dataset and read it's documentation. Create visualizations to answer the following questions:

# %%
swiss = pydataset.data('swiss', show_doc=True)
swiss = pydataset.data('swiss')
# Out:
# swiss
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Swiss Fertility and Socioeconomic Indicators (1888) Data
#
# ### Description
#
# Standardized fertility measure and socio-economic indicators for each of 47
# French-speaking provinces of Switzerland at about 1888.
#
# ### Usage
#
#     data(swiss)
#
# ### Format
#
# A data frame with 47 observations on 6 variables, each of which is in percent,
# i.e., in [0,100].
#
# [,1] Fertility Ig, "common standardized fertility measure" [,2] Agriculture
# [,3] Examination nation [,4] Education [,5] Catholic [,6] Infant.Mortality
# live births who live less than 1 year.
#
# All variables but 'Fert' give proportions of the population.
#
# ### Source
#
# Project "16P5", pages 549-551 in
#
# Mosteller, F. and Tukey, J. W. (1977) “Data Analysis and Regression: A Second
# Course in Statistics”. Addison-Wesley, Reading Mass.
#
# ...

# %%
swiss.info()
swiss.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, Courtelary to Rive Gauche
# Data columns (total 6 columns):
# Fertility           47 non-null float64
# Agriculture         47 non-null float64
# Examination         47 non-null int64
# Education           47 non-null int64
# Catholic            47 non-null float64
# Infant.Mortality    47 non-null float64
# dtypes: float64(4), int64(2)
# memory usage: 2.6+ KB
#        Fertility  Agriculture  Examination  Education   Catholic  \
# count  47.000000    47.000000    47.000000  47.000000   47.00000
# mean   70.142553    50.659574    16.489362  10.978723   41.14383
# std    12.491697    22.711218     7.977883   9.615407   41.70485
# min    35.000000     1.200000     3.000000   1.000000    2.15000
# 25%    64.700000    35.900000    12.000000   6.000000    5.19500
# 50%    70.400000    54.100000    16.000000   8.000000   15.14000
# 75%    78.450000    67.650000    22.000000  12.000000   93.12500
# ...

# %% [markdown]
# - Create an attribute named is_catholic that holds a boolean value of whether or not the province is Catholic. (Choose a cutoff point for what constitutes catholic)

# %%
is_catholic = swiss[swiss.Catholic > 60]

print(f"Catholic dataset \n{is_catholic.Fertility.describe()}")
print()
print(f"General Swiss public dataset \n{swiss.Fertility.describe()}")
# Out:
# Catholic dataset
# count    16.000000
# mean     80.550000
# std       8.229945
# min      65.000000
# 25%      75.950000
# 50%      80.900000
# 75%      84.625000
# max      92.500000
# Name: Fertility, dtype: float64
#
# General Swiss public dataset
# count    47.000000
# mean     70.142553
# std      12.491697
# min      35.000000
# 25%      64.700000
# 50%      70.400000
# 75%      78.450000
# max      92.500000
# Name: Fertility, dtype: float64

# %%
sns.relplot(data=is_catholic, x="Fertility", y="Catholic")
plt.title("> 45% Catholic Population Fetility Rate in 1888 Switzerland")


not_catholic = swiss[swiss.Catholic < 60]

sns.relplot(data=not_catholic, x="Fertility", y="Catholic")
plt.title("< 45% Catholic Population Fertility Rates in 1888 Switzerland")
# Out:
# Text(0.5, 1, '< 45% Catholic Population Fertility Rates in 1888 Switzerland')

# %% [markdown]
# - Does whether or not a province is Catholic influence fertility?

# %% [markdown]
# #### The evidence would depict so. But, there may be. more variables we arent analyzing. Like, there are some outliers in the no-so-catholic dataset where the fertility rating was > 80%, makes my wonder what was specifc to that area that wasn't so specific to the others

# %% [markdown]
# - What measure correlates most strongly with fertility?

# %%
sns.pairplot(data=swiss)

# %%
sns.relplot(data=swiss, x="Education", y="Fertility")
plt.title("Lower Education, Higher Fertility")
plt.show()

# %% [markdown]
# ### 4.) Using the chipotle dataset from the previous exercise, create a bar chart that shows the 4 most popular items and the revenue produced by each.

# %%
from env import user, password, host
chip_url = f'mysql+pymysql://{user}:{password}@{host}/chipotle'
orders = pd.read_sql('select * from orders', chip_url) 
#most_popular = orders.groupby('item_name').quantity.sum().nlargest(4)
#most_popular.describe()

orders.item_price = orders.item_price.str.replace("$", "").astype(float)
total = orders.groupby('item_name').item_price.sum().nlargest(4)
#total.dtype

total = total.to_frame()

#total.set_index([pd.Index([1, 2, 3, 4])])
total = total.reset_index()

# %%
chipotle = '''
SELECT 
    item_name, count(item_name) as count
FROM orders
GROUP BY item_name;
'''
#popularity = pd.read_sql(chipotle, chip_url)
#popularity


#most_popular = popularity.sort_values('count').tail(4)

#most_popular.item_price.str.replace("$", "").astype(float)

# %%
sns.barplot(data=total, x='item_name', y='item_price')
plt.show()

# %% [markdown]
# ### 5.) Load the sleepstudy data and read it's documentation. Use seaborn to create a line chart of all the individual subject's reaction times and a more prominant line showing the average change in reaction time.

# %%
sleep_study = pydataset.data('sleepstudy', show_doc=True)
sleep_study = pydataset.data('sleepstudy')
# Out:
# sleepstudy
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Reaction times in a sleep deprivation study
#
# ### Description
#
# The average reaction time per day for subjects in a sleep deprivation study.
# On day 0 the subjects had their normal amount of sleep. Starting that night
# they were restricted to 3 hours of sleep per night. The observations represent
# the average reaction time on a series of tests given each day to each subject.
#
# ### Format
#
# A data frame with 180 observations on the following 3 variables.
#
# `Reaction`
#
# Average reaction time (ms)
#
# `Days`
#
# Number of days of sleep deprivation
#
# `Subject`
#
# Subject number on which the observation was made.
#
# ### Details
#
# These data are from the study described in Belenky et al. (2003), for the
# sleep-deprived group and for the first 10 days of the study, up to the
# recovery period.
#
# ### References
#
# ...

# %%
sleep_study.info()

sleep_study
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 1 to 180
# Data columns (total 3 columns):
# Reaction    180 non-null float64
# Days        180 non-null int64
# Subject     180 non-null int64
# dtypes: float64(1), int64(2)
# memory usage: 5.6 KB
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 179  369.1417     8      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
plt.figure(figsize=(12, 10))



sns.lineplot(data=sleep_study, x='Reaction', y="Subject", hue="Subject", palette="Set2")
plt.show()

# %%
plt.figure(figsize=(20, 15))
unique_subject = sleep_study.groupby('Subject').Reaction.agg(['mean'])

sns.relplot(data=sleep_study, y='Reaction', x="Days", kind='line', hue='Subject', palette="Set1")
plt.plot([0, 9], [335, 350], linewidth=2)
plt.show()

# %%
len(list(sleep_study["Subject"].unique()))


sns.lmplot(data=sleep_study, x="Reaction", y="Subject")

# %%
sleep_study
# Out:
#      Reaction  Days  Subject  Avg_Reaction_Time
# 1    249.5600     0      308                NaN
# 2    258.7047     1      308                NaN
# 3    250.8006     2      308                NaN
# 4    321.4398     3      308                NaN
# 5    356.8519     4      308                NaN
# ..        ...   ...      ...                ...
# 176  329.6076     5      372                NaN
# 177  334.4818     6      372                NaN
# 178  343.2199     7      372                NaN
# 179  369.1417     8      372                NaN
# 180  364.1236     9      372                NaN
#
# [180 rows x 4 columns]
